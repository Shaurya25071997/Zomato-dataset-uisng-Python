# %% [markdown]
# ### All Restaurants in Gandhinagar scraped from Zomato

# %% [markdown]
# ### Data Cleaning in Datset

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\dell\Desktop\python\kai analytics 2\Intermediate projects\zomato\zomato_gandhinagar_data.csv")

# %%
df
# Out:
#                               name                      address cost_per_two  \
# 0                           Subway                     Infocity         ₹500
# 1                   Spices & Herbs                     Infocity         ₹700
# 2                       Terracotta  Airport Gandhinagar Highway       ₹1,000
# 3    Creamoholic Cafe & Restaurant  Airport Gandhinagar Highway         ₹700
# 4                   Domino's Pizza       Sector 11, Gandhinagar         ₹600
# ..                             ...                          ...          ...
# 531               Cafe Chocoaddict  Airport Gandhinagar Highway         ₹400
# 532              Greenz Restaurant                     Infocity         ₹700
# 533            Gurukrupa Food Zone  Airport Gandhinagar Highway         ₹400
# 534                        Foodsta  Airport Gandhinagar Highway         ₹400
# 535                   Sardar Foods                     Infocity         ₹500
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              536 non-null    object
#  1   address           536 non-null    object
#  2   cost_per_two      536 non-null    object
#  3   timings           536 non-null    object
#  4   category          459 non-null    object
#  5   cusine            536 non-null    object
#  6   detailed_address  536 non-null    object
#  7   featured_in       16 non-null     object
#  8   discount          41 non-null     object
# dtypes: object(9)
# memory usage: 37.8+ KB

# %%
df.isnull().sum()
# Out:
# name                  0
# address               0
# cost_per_two          0
# timings               0
# category             77
# cusine                0
# detailed_address      0
# featured_in         520
# discount            495
# dtype: int64

# %%
df = df.fillna('') #converting null values in empty string

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 536 entries, 0 to 535
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   name              536 non-null    object
#  1   address           536 non-null    object
#  2   cost_per_two      536 non-null    object
#  3   timings           536 non-null    object
#  4   category          536 non-null    object
#  5   cusine            536 non-null    object
#  6   detailed_address  536 non-null    object
#  7   featured_in       536 non-null    object
#  8   discount          536 non-null    object
# dtypes: object(9)
# memory usage: 37.8+ KB

# %%
df.sort_values(by=['featured_in'], ascending=[False])
# Out:
#                                        name  \
# 199                         Doner And Gyros
# 49                  Radhe Sweets And Snacks
# 73   Orchid - Fortune Inn Haveli Restaurant
# 39                            Pooja Parlour
# 171                                 Chezmoi
# ..                                      ...
# 179                             Mummas Food
# 178                            BMG Dosa Den
# 177                        Pandya Ice World
# 176      Capital Point Restaurant & Banquet
# 535                            Sardar Foods
#
#                                                address cost_per_two  \
# 199                        Airport Gandhinagar Highway         ₹500
# 49                              Sector 11, Gandhinagar         ₹250
# 73   Fortune Inn Haveli Restaurant, Sector 11, Gand...       ₹1,400
# 39                              Sector 21, Gandhinagar         ₹200
# 171  The Spicy Street Road, Airport Gandhinagar Hig...         ₹400
# ...

# %%
df.category.unique()
# Out:
# array(['Quick Bites', 'Casual Dining', 'Café', 'Dessert Parlor',
#        'Fine Dining', '', 'Sweet Shop', 'Food Truck', 'Bakery',
#        'Beverage Shop', 'Bhojanalya', 'Food Court', 'Dhaba', 'Kiosk'],
#       dtype=object)

# %%
df.cusine.unique()
# Out:
# array(['Healthy Food,Sandwich,Salad,Wraps,Fast Food',
#        'North Indian,Mexican,Chinese', 'North Indian,Italian,Chinese',
#        'Cafe,North Indian,Continental', 'Pizza,Fast Food',
#        'Desserts,Ice Cream',
#        'Cafe,Italian,North Indian,Continental,Beverages,Desserts',
#        'North Indian,Beverages',
#        'Pizza,Italian,Fast Food,Desserts,Beverages',
#        'North Indian,Chinese,South Indian', 'Cafe',
#        'Chinese,North Indian,Continental', 'North Indian,Chinese',
#        'North Indian,Chinese,Fast Food', 'North Indian,Street Food',
#        'North Indian,Chinese,Mexican,Fast Food',
#        'Fast Food,Chinese,North Indian,Desserts,Beverages',
#        'North Indian,Mughlai,Chinese', 'Cafe,Italian,Mexican,Desserts',
#        'South Indian', 'Mughlai,North Indian,South Indian',
#        'South Indian,Beverages,Ice Cream',
#        'Wraps,North Indian,Biryani,Fast Food', 'North Indian,Gujarati',
#        'Bengali,North Indian,Chinese',
# ...

# %%
df['cost_per_two']
# Out:
# 0        ₹500
# 1        ₹700
# 2      ₹1,000
# 3        ₹700
# 4        ₹600
#         ...
# 531      ₹400
# 532      ₹700
# 533      ₹400
# 534      ₹400
# 535      ₹500
# Name: cost_per_two, Length: 536, dtype: object

# %%
df.head(2)
# Out:
#              name   address cost_per_two                             timings  \
# 0          Subway  Infocity         ₹500         11am – 12midnight (Mon-Sun)
# 1  Spices & Herbs  Infocity         ₹700  12noon – 3pm, 7pm – 11pm (Mon-Sun)
#
#         category                                       cusine  \
# 0    Quick Bites  Healthy Food,Sandwich,Salad,Wraps,Fast Food
# 1  Casual Dining                 North Indian,Mexican,Chinese
#
#                                     detailed_address  \
# 0        Shop 1, Super Mall 1, Infocity, Gandhinagar
# 1   Swagat Rainforest 2, Opposite Swaminarayan Dh...
#
#                      featured_in discount
# 0
# 1  Outdoor Seating,Unique Dining

# %%
new=[]
for x in df['cost_per_two']:
    x=str(x[1:])
    x = x.replace(",", "")
    new.append(x)
df['cost_per_two']=new

# %%
df['cost_per_two'].iloc[1]
# Out:
# '900'

# %%
df = df.sort_values(by=['cost_per_two', 'address'], ascending=False)
df.head()
# Out:
#                    name                      address cost_per_two  \
# 15          Khana Shana                     Infocity          900
# 21   The Chocolate Room                     Infocity          900
# 17      7 Wonders Hotel  Airport Gandhinagar Highway          900
# 104           Indichini  Airport Gandhinagar Highway          900
# 51              Saffron                     Infocity          800
#
#                                       timings       category  \
# 15     11:30am – 3pm, 7pm – 10:30pm (Mon-Sun)  Casual Dining
# 21                    9:30am – 11pm (Mon-Sun)           Café
# 17                      11am – 10pm (Mon-Sun)  Casual Dining
# 104  12noon – 4pm, 7pm – 12midnight (Mon-Sun)  Casual Dining
# 51      12noon – 3:30pm, 7pm – 11pm (Mon-Sun)  Casual Dining
#
#                                                 cusine  \
# 15                            North Indian,Street Food
# 21                       Cafe,Italian,Mexican,Desserts
# ...

# %% [markdown]
# ### THE END
